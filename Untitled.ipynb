# %%
import pandas as pd
import utilities as ut
import networkx as nx
import numpy as np
import Complexity as cx
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("real_networks/processed/dolphins.csv")
G = ut.df_to_network(df)
nx.draw(G)

# %%
step_prob = 0.05
prob_list = np.linspace(0,1,int(1/step_prob))
sample = 50

# %%
dol_result = [0]*len(prob_list)
for iter_n in range(sample):
    G1 = G.copy()
    for i in range(int(1/step_prob)):
        G2 = G1.copy()
        G1 = ut.single_link_rewiring(G2, step_prob)
        dol_result[i] = dol_result[i] + cx.OdC(G1)
dol_result = [item/sample for item in dol_result]
dol_result.insert(0,cx.OdC(G))
prob_list = np.linspace(0,1,int(1/step_prob)+1)

# %%
plt.plot(prob_list,dol_result)
