# %%
from rewiring import rewiring
import matplotlib.pyplot as plt

# %%
index = ["dolphins","pdzbase","GBPT_train",
         "hamsterster","Roget","flight"]
index_bus = ["london","paris","berlin","sydney","detroit","beijing"]

# %%
real_networks = [rewiring(item) for item in index]
bus_networks = [rewiring(item,bus = True) for item in index_bus]

# %%
real_networks[5].one_stop("P",2)

# %%
for niter in range(50):
    for item in bus_networks:
        item.experiment("S",1)
        item.write_result("S")
        item.experiment("P",1)
        item.write_result("P")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-d3df62d070aa> in <module>
#       1 for niter in range(50):
#       2     for item in bus_networks:
# ----> 3         item.experiment("S",1)
#       4         item.write_result("S")
#       5         item.experiment("P",1)
#
# ~\Documents\GitHub\Project\rewiring.py in experiment(self, method, sample_number)
#     102         for i in range(sample_number):
#     103             self.clear_rewiring()
# --> 104             self.continuous_rewiring(method)
#     105             self.record_result(method)
#     106     #Plot the results
#
# ~\Documents\GitHub\Project\rewiring.py in continuous_rewiring(self, method)
#      43             niter = int(1/self.step_prob)
#      44             for i in range(niter):
# ---> 45                 self.single_link_rewiring()
#      46                 self.result.append(cx.OdC(self.rewired_G))
#      47             self.s_n += 1
#
# ~\Documents\GitHub\Project\rewiring.py in single_link_rewiring(self)
#      28     #Carry out one step of single link rewiring
#      29     def single_link_rewiring(self):
# ---> 30         self.rewired_G = ut.single_link_rewiring(self.rewired_G,self.step_prob)
#      31     #Carry out one step of pairwise rewiring
#      32     def pairwise_rewiring(self):
#
# ~\Documents\GitHub\Project\utilities.py in single_link_rewiring(G, prob)
#     333             remove_neighbor = random.choice(neighbors)
#     334             G1.remove_edge(source,remove_neighbor)
# --> 335             if not nx.is_connected(G1):
#     336                 G1.add_edge(source,remove_neighbor)
#     337                 #print(nx.is_connected(G1))
#
# <decorator-gen-297> in is_connected(G)
#
# ~\anaconda3\lib\site-packages\networkx\utils\decorators.py in _not_implemented_for(not_implement_for_func, *args, **kwargs)
#      76             raise nx.NetworkXNotImplemented(msg)
#      77         else:
# ---> 78             return not_implement_for_func(*args, **kwargs)
#      79
#      80     return _not_implemented_for
#
# ~\anaconda3\lib\site-packages\networkx\algorithms\components\connected.py in is_connected(G)
#     136             "Connectivity is undefined ", "for the null graph."
#     137         )
# --> 138     return sum(1 for node in _plain_bfs(G, arbitrary_element(G))) == len(G)
#     139
#     140
#
# ~\anaconda3\lib\site-packages\networkx\algorithms\components\connected.py in _plain_bfs(G, source)
#     184             if v not in seen:
#     185                 seen.add(v)
# --> 186                 nextlevel.update(G_adj[v])
#     187     return seen
#
# ~\anaconda3\lib\site-packages\networkx\classes\coreviews.py in __iter__(self)
#      46
#      47     def __iter__(self):
# ---> 48         return iter(self._atlas)
#      49
#      50     def __getitem__(self, key):
#
# KeyboardInterrupt:

# %%
for item in bus_networks:
    plt.figure()
    item.plot_result("P+S")
