# %%
from rewiring import rewiring
import matplotlib.pyplot as plt
import numpy as np

# %%
index = ["dolphins","pdzbase","GBPT_train",
         "hamsterster","Roget","flight"]
index_bus = ["london","paris","berlin","sydney","detroit","beijing"]

# %%
real_networks = [rewiring(item) for item in index]
bus_networks = [rewiring(item,bus = True) for item in index_bus]

# %%
for niter in range(10):
    for item in real_networks:
        item.experiment("P",1)
        item.write_result("P")
        item.experiment("S",1)
        item.write_result("S")
    for item in bus_networks:
        item.experiment("P",1)
        item.write_result("P")
        item.experiment("S",1)
        item.write_result("S")

# %%
for niter in range(10):    
    for item in bus_networks:
        item.experiment("P",1)
        item.write_result("P")
        item.experiment("S",1)
        item.write_result("S")

# %%
fig,axes = plt.subplots(6,2,figsize = (10,25))
for i in range(len(real_networks)):
    step_prob = 0.05
    prob_list = np.linspace(0,1,int(1/(step_prob)+1))
    mean = [np.mean(row) for index, row in real_networks[i].s_result.iterrows()]
    std = [np.std(row) for index, row in real_networks[i].s_result.iterrows()]
    axes[i][0].errorbar(prob_list,mean,yerr = std,color = "black",label = "Single link rewiring")
    mean = [np.mean(row) for index, row in real_networks[i].p_result.iterrows()]
    std = [np.std(row) for index, row in real_networks[i].p_result.iterrows()]
    axes[i][0].errorbar(prob_list,mean,yerr = std,color = "blue",label = "Pairwise rewiring")
    axes[i][0].set_ylabel("$MA_{RI}$")
for i in range(len(bus_networks)):
    step_prob = 0.05
    prob_list = np.linspace(0,1,int(1/(step_prob)+1))
    mean = [np.mean(row) for index, row in bus_networks[i].s_result.iterrows()]
    std = [np.std(row) for index, row in bus_networks[i].s_result.iterrows()]
    axes[i][1].errorbar(prob_list,mean,yerr = std,color = "black",label = "Single link rewiring")
    mean = [np.mean(row) for index, row in bus_networks[i].p_result.iterrows()]
    std = [np.std(row) for index, row in bus_networks[i].p_result.iterrows()]
    axes[i][1].errorbar(prob_list,mean,yerr = std,color = "blue",label = "Pairwise rewiring")

axes[0][0].set_title("Real networks")
axes[0][1].set_title("Modified bus networks")
axes[5][0].set_xlabel("Rewiring probability")
axes[5][1].set_xlabel("Rewiring probability")
axes[0][0].legend()
axes[5][1].legend()
plt.savefig("figures/rewiring.eps",format="eps")
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
item.p_result
# Out:
#            1         2         3         4         5         6         7  \
# 0   0.720814  0.720814  0.720814  0.720814  0.720814  0.720814  0.720814
# 1   0.721629  0.721538  0.721438  0.721721  0.721602  0.721566  0.721682
# 2   0.722269  0.722214  0.722025  0.722460  0.722252  0.722193  0.722352
# 3   0.722736  0.722850  0.722750  0.723018  0.722863  0.722606  0.722880
# 4   0.723208  0.723331  0.723255  0.723440  0.723360  0.722964  0.723320
# 5   0.723696  0.723782  0.723666  0.723804  0.723738  0.723484  0.723662
# 6   0.724010  0.724103  0.724071  0.724122  0.724022  0.723844  0.724017
# 7   0.724263  0.724380  0.724342  0.724420  0.724258  0.724120  0.724242
# 8   0.724492  0.724599  0.724538  0.724656  0.724479  0.724342  0.724490
# 9   0.724695  0.724733  0.724748  0.724775  0.724652  0.724471  0.724659
# 10  0.724839  0.724860  0.724899  0.724956  0.724809  0.724620  0.724815
# 11  0.724953  0.724969  0.724984  0.725066  0.724897  0.724730  0.724927
# 12  0.725007  0.725075  0.725047  0.725173  0.724993  0.724790  0.724977
# 13  0.725053  0.725141  0.725114  0.725199  0.725103  0.724836  0.725084
# 14  0.725081  0.725138  0.725142  0.725209  0.725164  0.724859  0.725089
# 15  0.725064  0.725125  0.725161  0.725197  0.725212  0.724835  0.725093
# 16  0.725024  0.725121  0.725208  0.725092  0.725210  0.724800  0.725065
